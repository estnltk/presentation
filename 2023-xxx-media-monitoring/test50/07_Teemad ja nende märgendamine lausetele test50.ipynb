# %% [markdown]
# ## Teemad ja nende märgendamine lausetele test50

# %% [markdown]
# Süntaksianalüüsi tulemusel saadi sagedusloend lauses nimeüksuste alluvateks (children) olevatest omadussõnalistest täienditest (amod, mis kirjeldavad nimeüksuse omadusi), nimeüksuste ülemuseks (parent) olevatest verbidest (kirjeldavad, mida nimeüksus lauses teeb) ning nende ülemuste alluvateks olevatest määrustest (advmod, mis kirjeldavad tegevuse viisi, kohta, aega vms). Järgnevalt tuleb jaotada laused klassidesse.

# %%
from estnltk import Text
from estnltk.taggers.system.rule_taggers import AmbiguousRuleset, Ruleset, StaticExtractionRule
from estnltk.taggers import PhraseTagger
import sqlite3
from estnltk.converters import json_to_text
from estnltk.converters import text_to_json
import csv
from collections import Counter

# %% [markdown]
# ### I sõnavara ja laused

# %% [markdown]
# Temaatiliste märksõnade valikul võib olla abiks süntaksianalüüsi teel saadud sõnaloendist teatava sagedusega sõnade välja sorteerimine, kuid lõplik märksõnade loend tuleb koostada käsitsi.

# %%
with open('verbs_amods_advmods_frequencies.csv', encoding='UTF-8') as csv_file:
    rows = []
    reader = csv.DictReader(csv_file)
    for row in reader:
        rows.append(row)

# %%
len(rows)
# Out:
# 1372

# %%
rows_more_common = []

# %%
for i in range(len(rows)):
    if i == 0:
        continue
    if int(rows[i]['freq']) > 1:
        rows_more_common.append(rows[i])

# %%
rows_more_common[:20]
# Out:
# [{'lemma': 'hea', 'freq': '4', 'value': 'amod'},
#  {'lemma': 'peamine', 'freq': '2', 'value': 'amod'},
#  {'lemma': 'kukkuma', 'freq': '10', 'value': 'verb'},
#  {'lemma': 'juhtuma', 'freq': '2', 'value': 'verb'},
#  {'lemma': 'tegema', 'freq': '57', 'value': 'verb'},
#  {'lemma': 'saama', 'freq': '65', 'value': 'verb'},
#  {'lemma': 'jätkama', 'freq': '111', 'value': 'verb'},
#  {'lemma': 'minema', 'freq': '28', 'value': 'verb'},
#  {'lemma': 'olema', 'freq': '33', 'value': 'verb'},
#  {'lemma': 'küsima', 'freq': '5', 'value': 'verb'},
#  {'lemma': 'lugema', 'freq': '6', 'value': 'verb'},
#  {'lemma': 'vaatama', 'freq': '12', 'value': 'verb'},
#  {'lemma': 'teadma', 'freq': '19', 'value': 'verb'},
#  {'lemma': 'esinema', 'freq': '6', 'value': 'verb'},
#  {'lemma': 'lootma', 'freq': '2', 'value': 'verb'},
#  {'lemma': 'arvama', 'freq': '10', 'value': 'verb'},
#  {'lemma': 'kandideerima', 'freq': '12', 'value': 'verb'},
#  {'lemma': 'käima', 'freq': '15', 'value': 'verb'},
#  {'lemma': 'ütlema', 'freq': '90', 'value': 'verb'},
#  {'lemma': 'esitama', 'freq': '13', 'value': 'verb'}]

# %%
with open('thematic_keywords.csv', encoding='UTF-8') as csv_file:
    rows = []
    reader = csv.DictReader(csv_file)
    for row in reader:
        rows.append(row)

# %%
print(rows)
# Out:
# [{'lemma': 'callable', 'class': 'string'}, {'lemma': "'vastanduma',", 'class': 'vaidlused ja erimeelsused'}, {'lemma': "'võitlema',", 'class': 'vaidlused ja erimeelsused'}, {'lemma': "'häbistama',", 'class': 'vaidlused ja erimeelsused'}, {'lemma': "'vaidlema',", 'class': 'vaidlused ja erimeelsused'}, {'lemma': "'nokkima',", 'class': 'vaidlused ja erimeelsused'}, {'lemma': "'kandideerima',", 'class': 'valimised'}, {'lemma': "'valima',", 'class': 'valimised'}, {'lemma': "'võitma',", 'class': 'valimised'}, {'lemma': "'lubama',", 'class': 'valimised'}, {'lemma': "'hääletama',", 'class': 'valimised'}, {'lemma': "'valetama',", 'class': 'valetamine'}, {'lemma': "'varjama',", 'class': 'valetamine'}, {'lemma': "'mustama',", 'class': 'valetamine'}, {'lemma': "'kuritarvitama',", 'class': 'valetamine'}, {'lemma': "'juhtima',", 'class': 'valitsemine'}, {'lemma': "'otsustama',", 'class': 'valitsemine'}, {'lemma': "'kaasama',", 'class': 'valitsemine'}, {'lemma': "'mõjutama',", 'class': 'valitsemine'}, {'lemma': "'esindama',", 'class': 'valitsemine'}, {'lemma': "'juhtima',", 'class': 'valitsemine'}]

# %% [markdown]
# Andmebaasist loetakse süntaktilise analüüsi kihiga laused.

# %%
sentences = []
sentence_ids = []

# %%
con = sqlite3.connect("media_data_2.db")
cur = con.cursor()

# %%
for row in cur.execute("SELECT ID, sentence FROM sentences_syntax_analysis"):
    sentence_id = row[0]
    sentence = json_to_text(json_text=row[1])
    sentences.append(sentence)
    sentence_ids.append(sentence_id)

# %%
con.close()

# %% [markdown]
# ### PhraseTagger märksõnade lausetele märkimiseks

# %%
vocabulary_file = 'thematic_keywords.csv'
ruleset = Ruleset()
ruleset.load(file_name=vocabulary_file, key_column='lemma')

# %%
phrasetagger = PhraseTagger(output_layer='keywords',
                      input_layer='morph_analysis',
                      input_attribute='lemma',
                      ruleset=ruleset,
                      output_attributes=['class'],
                      #decorator=decorator,
                      conflict_resolver='KEEP_MAXIMAL',
                      ignore_case=True)

# %%
# Lausetele märgitakse peale märksõnade kiht
for sentence in sentences:
    phrasetagger.tag(sentence)

# %%
sentences_with_keywords = []

for sentence in sentences:
    if len(sentence.keywords) > 0:
        sentences_with_keywords.append(sentence)

display(sentences_with_keywords[20])
display(sentences_with_keywords[20].keywords)
display(sentences_with_keywords[20].stanza_ensemble_syntax)
# Out:
# Text(text='Kes ja kuidas seal hääletuse igal juhul selle salajase hääletuse tulemusega siis valiti pressivaenlaseks president ilves ja mittelang kuigi ütlen ausalt lang oli selles nimekirjas.')
# Layer(name='keywords', attributes=('class',), spans=SL[EnvelopingSpan(['valiti'], [{'class': 'valimised'}])])
# Layer(name='stanza_ensemble_syntax', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc', 'parent_span', 'children'), spans=SL[Span('Kes', [{'id': 1, 'lemma': 'kes', 'upostag': 'P', 'xpostag': 'P', 'feats': {'pl': 'pl', 'nom': 'nom'}, 'head': 13, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('ja', [{'id': 2, 'lemma': 'ja', 'upostag': 'J', 'xpostag': 'J', 'feats': {'sub': 'sub', 'crd': 'crd'}, 'head': 3, 'deprel': 'cc', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('kuidas', [{'id': 3, 'lemma': 'kuidas', 'upostag': 'D', 'xpostag': 'D', 'feats': {}, 'head': 1, 'deprel': 'conj', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('seal', [{'id': 4, 'lemma': 'seal', 'upostag': 'D', 'xpostag': 'D', 'feats': {}, 'head': 13, 'deprel': 'advmod', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('hääletuse', [{'id': 5, 'lemma': 'hääletus', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'gen': 'gen'}, 'head': 13, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('igal', [{'id': 6, 'lemma': 'iga', 'upostag': 'P', 'xpostag': 'P', 'feats': {'sg': 'sg', 'ad': 'ad'}, 'head': 7, 'deprel': 'det', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('juhul', [{'id': 7, 'lemma': 'juht', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'ad': 'ad'}, 'head': 13, 'deprel': 'obl', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('selle', [{'id': 8, 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': {'sg': 'sg', 'gen': 'gen'}, 'head': 10, 'deprel': 'det', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('salajase', [{'id': 9, 'lemma': 'salajane', 'upostag': 'A', 'xpostag': 'A', 'feats': {'pos': 'pos', 'sg': 'sg', 'gen': 'gen'}, 'head': 10, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('hääletuse', [{'id': 10, 'lemma': 'hääletus', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'gen': 'gen'}, 'head': 11, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('tulemusega', [{'id': 11, 'lemma': 'tulemus', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'kom': 'kom'}, 'head': 13, 'deprel': 'obl', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('siis', [{'id': 12, 'lemma': 'siis', 'upostag': 'D', 'xpostag': 'D', 'feats': {}, 'head': 13, 'deprel': 'advmod', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('valiti', [{'id': 13, 'lemma': 'valima', 'upostag': 'V', 'xpostag': 'V', 'feats': {'aux': 'aux', 'indic': 'indic', 'impf': 'impf', 'imps': 'imps', 'af': 'af'}, 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': <class 'tuple'>}]),
# Span('pressivaenlaseks', [{'id': 14, 'lemma': 'pressivaenlane', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'tr': 'tr'}, 'head': 13, 'deprel': 'xcomp', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('president', [{'id': 15, 'lemma': 'president', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'nom': 'nom'}, 'head': 13, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('ilves', [{'id': 16, 'lemma': 'ilves', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'nom': 'nom'}, 'head': 15, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('ja', [{'id': 17, 'lemma': 'ja', 'upostag': 'J', 'xpostag': 'J', 'feats': {'sub': 'sub', 'crd': 'crd'}, 'head': 18, 'deprel': 'cc', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('mittelang', [{'id': 18, 'lemma': 'mittelang', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'nom': 'nom'}, 'head': 15, 'deprel': 'conj', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('kuigi', [{'id': 19, 'lemma': 'kuigi', 'upostag': 'D', 'xpostag': 'D', 'feats': {}, 'head': 20, 'deprel': 'mark', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('ütlen', [{'id': 20, 'lemma': 'ütlema', 'upostag': 'V', 'xpostag': 'V', 'feats': {'main': 'main', 'indic': 'indic', 'pres': 'pres', 'ps1': 'ps1', 'sg': 'sg', 'ps': 'ps', 'af': 'af'}, 'head': 13, 'deprel': 'conj', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('ausalt', [{'id': 21, 'lemma': 'ausalt', 'upostag': 'D', 'xpostag': 'D', 'feats': {}, 'head': 20, 'deprel': 'advmod', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('lang', [{'id': 22, 'lemma': 'lang', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'nom': 'nom'}, 'head': 25, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('oli', [{'id': 23, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': {'aux': 'aux', 'indic': 'indic', 'impf': 'impf', 'ps3': 'ps3', 'sg': 'sg', 'ps': 'ps', 'af': 'af'}, 'head': 25, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('selles', [{'id': 24, 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': {'sg': 'sg', 'in': 'in'}, 'head': 25, 'deprel': 'det', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('nimekirjas', [{'id': 25, 'lemma': 'nimekiri', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'sg': 'sg', 'in': 'in'}, 'head': 13, 'deprel': 'conj', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('.', [{'id': 26, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': {}, 'head': 25, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}])])

# %% [markdown]
# Kuigi märksõna lausest leiti, ei pruugi see olla lauses seotud huvipakkuva isiku/organisatsiooniga. Seetõttu tuleb võtta arvesse ka süntaksianalüüsi kihti, et teha kindlaks, kas leitud märksõna esineb lauses seoses isiku/organisatsiooniga (kas täiendi, verbi või määruse positsioonil).

# %%
phrase = []

# %%
for entity in sentences_with_keywords[20].entity_phrases:
    for span in entity:
        phrase.append(span)

# %%
print(phrase)
# Out:
# [Span('ilves', [{'normalized_text': 'ilves', 'lemma': 'ilves', 'root': 'ilves', 'root_tokens': ['ilves'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}])]

# %%
keywrds = []

# %%
for word in sentences_with_keywords[20].keywords:
    keywrds.append(word[0])

# %%
print(keywrds)
# Out:
# [Span('valiti', [{'normalized_text': 'valiti', 'lemma': 'valima', 'root': 'vali', 'root_tokens': ['vali'], 'ending': 'ti', 'clitic': '', 'form': 'ti', 'partofspeech': 'V'}])]

# %%
for subspan in phrase:
    parent = sentences_with_keywords[20].stanza_ensemble_syntax.get(subspan)['parent_span']
    parent_word = sentences_with_keywords[20]['words'].get(parent) 
    if parent_word in phrase:
        continue
    parent_morph = sentences_with_keywords[20].morph_analysis.get(parent)
    if 'V' not in parent_morph['partofspeech']:
        continue
    print(parent['lemma'])
    print('Kas on ülemus: ', parent_morph in keywrds)
    
    # Verbist ülemuse alluv, kui on määrus
    parent_children = sentences_with_keywords[20].stanza_ensemble_syntax.get(parent)['children']
    if len(parent_children) > 1:
        for child in parent_children:
            child_word = sentence['words'].get(child) 
            if child_word in phrase:
                continue
            elif 'advmod' != child['deprel']:
                continue
            if child == keywrds[0]:
                print(child['lemma'])
                print('Kas on ülemuse alluv: ', child == keywrds[0])
                break
            print(child['lemma'])
            print('Kas on ülemuse alluv: ', child == keywrds[0])
            
    children = sentences_with_keywords[20].stanza_ensemble_syntax.get(subspan)['children']
    if len(children) > 0:
        for child in children:
            child_word = sentences_with_keywords[20]['words'].get(child) 
            if child_word in phrase:
                continue
            elif 'amod' != child['deprel']:
                continue
            if child == keywrds[0]:
                print(child['lemma'])
                print('Kas on alluv: ', child == keywrds[0])
                break
            print(child['lemma'])
            print('Kas on alluv: ', child == keywrds[0])
    
    print(list(s.text for s in phrase))
    print(parent['lemma'])

# %% [markdown]
# Kõigil lausetel:

# %%
sentences_with_classes = []

# %%
for sentence in sentences_with_keywords:
    keywrds = []
    for word in sentence.keywords:
        keywrds.append(word[0])
        
    classes = []
    
    for entity in sentence.entity_phrases:
        phrase = []
        for span in entity:
            phrase.append(span)
    
        for subspan in phrase:
            parent = sentence.stanza_ensemble_syntax.get(subspan)['parent_span']
            if parent != None:
                # Verbist ülemus
                parent_morph = sentence.morph_analysis.get(parent)
                if 'V' not in parent_morph['partofspeech']:
                    continue
                for i in range(len(keywrds)):
                    if keywrds[i] == parent_morph:
                        cl = sentence['keywords'][i]['class']
                        classes.append(cl)
                # Verbist ülemuse alluv, kui on määrus
                parent_children = sentence.stanza_ensemble_syntax.get(parent)['children']
                if len(parent_children) > 1:
                    for child in parent_children:
                        if 'advmod' != child['deprel']:
                            continue
                        child_morph = sentence.morph_analysis.get(child)
                        for i in range(len(keywrds)):
                            if keywrds[i] == child_morph:
                                cl = sentence['keywords'][i]['class']
                                classes.append(cl)
                                
            
            # Täiendid
            children = sentence.stanza_ensemble_syntax.get(subspan)['children']
            if len(children) > 0:
                for child in children:
                    if 'amod' != child['deprel']:
                        continue
                    child_morph = sentence.morph_analysis.get(child)
                    for i in range(len(keywrds)):
                        if keywrds[i] == child_morph:
                            cl = sentence['keywords'][i]['class']
                            classes.append(cl)
    key = tuple(classes)
    value = [sentence]
    if len(classes) > 0:
        sentences_with_classes.append(dict(zip(key, value)))

# %%
len(sentences_with_classes)
# Out:
# 67

# %%
display(sentences_with_classes)
# Out:
# [{'valimised': Text(text='Teatas et ta kavatseb ka riigikokku kandideerida kevadel et kuidas ta hakkab seal töötama sotside fraktsioonis kus Eiki nestoriga kestev kas tema elust tõmbuksid linnast oma soojast peadest välja kangust.')},
#  {'vaidlused ja erimeelsused': Text(text='Keskerakond reformierakond omaette vastanduma ja on hinnatud isegi üllatas et et et ma ise olin maha maganud et Margus Tsahkna seda teemat niimoodi tõstatas ja tegelikult ka IRLile on see.')},
#  {'valitsemine': Text(text='Selle asemel et ma kunagi kunagi küsisin ka kohtasin tänaval laval Andres tarandit ja siis ka Indrek tarand oli Euroopa parlamendi liikmest pärast pikka mari mineerimist otsustanud ennast.')},
#  {'valimised': Text(text='Tartus on Rein kilk Tallinnas ajakirjanikud aga võidan ja Ainar uus alustaks sellest millest kirjutas äripäev ehk siis läheks sellest palvest ehkki praegu kalendri järgi ju täiesti tavaline sügisilm peaks olema läheme sellest talvest suvisele Kreeta saarel.')},
#  {'valitsemine': Text(text='Ja Rein lang kes kes ütles et et riigikogus esinedes et ta jääb nüüd huviga seda seda suurepärast sündmust ootama ja ja loodab et üks ja esimesel korrusel ma võin kinnitada et täna hommikul oli oli Allar Jõks teiste elusid ilmselt elada Taskendis esimese korruse aga aga aga ma ei jooks Jõks juhtis tähelepanu sellele et.')},
#  {'valitsemine': Text(text='Eesti aeti mis mõjutaks ajakirjandus ehk siis kuidas Reiljanist või nõuda et ajakirjandusmäära kuvandi ja Eesti ajakirjanduses löönud nagu savisaarest savisaarest moekuvand et et.')},
#  {'valimised': Text(text='Mida ma aga olen kuulnud et tegelikult Eesti energia mingisugust igasugune New lubab selle põlevkivimassiivide tegutsemis ongi ainult antud uurimiseks aga kaevandamisluba hilisemaks ajaks ei ole.')},
#  {'valitsemine': Text(text='Noh ma arvan et ma ei reeda seda kitsas mõttes oli suurusjärgu võrra kõrgem ehk oleme õigel teel et siin küsimus ongi selles et seda on Eesti energia nüüd küll oled otsustanud ära ei lähe ostma mitte mingit vara kui selleks on ka põlevkivi ja kui me saame see väga odav me ei ole seda vaja leida just ainumaja kohta kuu ei taha.')},
#  {'valimised': Text(text='üritabki nüüd mängida ja Eesti kõige demokraatlikumat erakonda reformierakonnast kandideeris Ansip üksi presidendiks nad tahtsid ka üksi siin ainult ilvese kandideerima panna ja ja.')},
#  {'valimised': Text(text='Minu jaoks ei ole väga vahet antud hetkel kas Jüri ratas kandideerib või mitte.')},
#  {'valitsemine': Text(text='Ja selles mõttes on kõik ja uus kui keskerakonda tegelikult juhib Edgar savisaar ja ta valitakse tagasi siis minule meeldib et et et erakonda juhib see mees kes tegelikult seda juhib.')},
#  {'valitsemine': Text(text='Noh ära lollitatud siis tegelikult juhib savisaar ja siis see valivad äkki usuvad et too rataste midagi uut ja lõpuks on nii nime teadlase savisaare võimsana.')},
#  {'valitsemine': Text(text='Suse suhteliselt rahulikult ma olen täiesti veendunud et kui kogu seda protsessi juhiks näiteks Jüri ratas linnapeana kes nüüd.')},
#  {'valitsemine': Text(text='Eile luuser täna võita siis soovib ka meenutada et keksis lahkunud ta juhtis Tiit lapse kes teatavasti seitsmekümne kuuendal aastal asutas firma kaheks viiendal aastal ka üldiselt välja üheksakümne kaheksal aastal peab küll oli.')},
#  {'valitsemine': Text(text='Sinna et tegin seda teistega siin kaalus kalas vastutab kõige rohkem mu minu panus oli ideoloogiline mulle roll ka Kallas juhtis kogu aeg.')},
#  {'valimised': Text(text='Ei võida mitte keegi et see kulutus on täiesti kasutu aga samas ma tajun selles mingisugust samasugust konksu või või reha kuhu nad komistama et kui oli europarlamendi valimistel see suletud nimekirja tegemine milles siis Indrek tarand võitis nagu.')},
#  {'vaidlused ja erimeelsused': Text(text='Peda natuke valeta natuke juhi tähelepanu kõrvale ja see on ju tegelikult see mehhanism mis on tänaseks välja tuleb meil ei ole mõtet vaielda reformierakonna.')},
#  {'valimised': Text(text='Olulisemast võib-olla see et sellesse valitsusse eelnõusse viidi siiski sisse palju parandusi kaks sisulist mis jõudis saali mida hääletati vastu hääletajaid oli Juku-Kalle raid ja Igor Gräzin Norra raku asukas töö suunas avanes teatamisLukase erapooletuks et selle pojal nagu.')},
#  {'valitsemine': Text(text='Et Pentus-Rosimannus on otsustanud Reformierakonna toetuse siiski mängida ning see viie protsendi piirimaile ja head teed teil minna iga minul selle vastu midagi oleks iga kuritegu peabki päevavalgele tulema ja ja kahjuks siiski eesti rahva enamik alates juba Kaupo ja Lembitu aegadest on siiski.')},
#  {'valitsemine': Text(text='Tähelepanelikult tasuks seda süüdistust uurida et kas tõesti Aivar Kokk mõjutab Riigikogus seaduste vastuvõtmist mis puudutab siis kava kava püüdmist Peipsi järvel.')},
#  {'valimised': Text(text='Mis piirid ja ma olen küll imeks seda et me valime valimi siis ühel või teisel kombel Riigikogusse rahvaesindajad ja ja pool nendest on sinna sattunud müügi teisel kombel et me ei olegi nagu kassid juures kuskile et valimas aga see soov.')},
#  {'valimised': Text(text='Et et sul ei ole nii-öelda alustamiseks alanedes kakssada viiskümmend liiget aga kui sa tahad juba Riigikokku kandideerida peaks olema viissada liiget seal on võimalik ka nagu seda seda arengut ka nüüd kuidagipidi kirjeldada nii et sulepea seda kohe paugust olema.')},
#  {'valimised': Text(text='Ja minu meelest kõik need inimesed kes Riigikokku kandideerinud sinna avalikuks asub aga siin öeldakse muid esinejate kindel asi on oodatud siin on jutt esitus kogus oli Riigikogus esimesel Riigikogu omavalitsused saama siis ma tean ja ka maailmas alati omavalitsusi.')},
#  {'valimised': Text(text='Ja ja kus osutus valituks siis tuleb see asemel asendusliige sellepärast et sa ei saa olla korraga Riigikogu omavalitsuskogu liige nüüd kui sa näiteks kahe aasta pärast sündi valitava Riigikogusse kui sa ise kandideerisin siis sa saad selle nagu mandaadi tagas endale eksamid siis naasta.')},
#  {'valimised': Text(text='Eks see oli sinu sinu sinu väitest osa praegu aru et see on nagu nagu pehmet paati poliitikud tagumiku all et ei ole kui mina Riigikogu tagasi valida siis ma olen ning igal juhul saame kaks aastat Tartu volikogus.')},
#  {'valitsemine': Text(text='Suuremad teed distsipliini ehk seda esindab siis Postimees Mikk Salu kes ütleb et ta Ansipile oleks on Ansipil oleks tarvis paremini kontrollida kuna kuna erakond on kasvanud suureks eks ole Ansipi on parteijuhiks saamist alates neljast tuhandest kolme meeskonna.')},
#  {'valitsemine': Text(text='Esimene paragrahv juba on minu imestuseks minu meelest põhiseadusega vastuolus kuid peegeldab väga hästi Riigikogus esindatud erakondaste pisukest mõttemaailmaeetika käinud endal oleks ja ja ma loen selle ettesiis.')},
#  {'valimised': Text(text='eks tehtud ettepanekud kõrvale panna, siis\nma nagu kahe käega hääletaks tulumaksu osas Iiri ettepaneku poolt\nmitte Reformierakonna poolt Reformierakond tahaks tõsta kõigil maksuvaba miinimumi aga noh inimene, eks, et, et kes kes saab noh näiteks kaks tuhat eurot kuus palka, eks, et temale, nagu see võidetud viisteist eurot on noh nagu pole probleem suhteliselt ükskõik\neks noh irli ettepanek nüüd nagu nendele madalamapalgalistele teha tulumaksu osas soodustusi oleks nagu oluliselt täpsemalt suunatud ja samas ei läheks ta riigikassale ka nii palju maksma kui Reformierakonna ettepanek')},
#  {'valimised': Text(text='Tõsi, valitsuse kokku pannud Reformierakond ei ole ka midagi sarnast oma valijatele lubanud.')},
#  {'valimised': Text(text='No ütleme niimoodi, et minu jaoks kannab see koalitsioonileping sellise inimese nagu Rain Rosimannus, näpujälgi ja see on esiteks juba väga halb, sest Rain Rosimannus teatavasti on mitte keegi ei kandideerinud valimistel ei kogunud ühtegi häält ja miks tema seal kogu aeg õiendab ja neid juhendab nii Reformierakonna ministreid\nja koalitsioonilepingus on ka samuti väga umbmääraselt sõnastatud\nkaks väga kriitilist asja.')},
#  {'valitsemine': Text(text='ja et siis Eesti riigikohus otsustas ju tookord, et pidas Delfit anonüümselt au teatud kommentaaride eest vastutavaks, et see ongi nagu selle küsimuse nagu kogu iva ongi siin tegu on anonüümsete kommentaaridega ja et kas portaalipidaja peaks siis vastutama nende oma\nau teotavad anonüümsete kommentaaride eest, et minu seisukoht on siin.')},
#  {'valitsemine': Text(text='üllatab jah, et omal ajal, kui, kui Sandor Liive juhtis Eesti Energiat, siis kuna ta panustab väga palju nii-öelda suhtekorraldusele oma töösse, siis ta suutis seal väga edukalt suhtekorralduslikult\nluua endast kuvandi kui ühest superjuhist Eesti Energia ametis isegi kui see tegelikkuses nii ei olnud, siis see\nsiis nüüd on pööranud saja kaheksakümnekraadine nüüd hullemad nagu kommunikatsiooni ja seda protsessi nagu\navalikkuse ette tuua, isegi kui seadus on, on, on kogu seda protsessi raskendab siis.')},
#  {'valitsemine': Text(text='palun, unustage siiski seda, et, et Tartu rahuajalooliselt on tõesti olemas olnud ja isegi mainega ja, ja, ja üks, et, et neid inimesi, kelle seisukohti siis Margus Tsahkna siis see esindab neid inimesi on ikka Eestisse, nii nagu ma,\nma usun seda, et neid inimesi on ikka väga palju, kes arvavad, et, et Tartu raha tuleb ära märkida, et et seda me nägime juba siis eelmisel katsel piirilepingut sõlmida, kui tehti sisse preambula sinna, kas nüüd on sinna üht lauset veel juurde vaja, see on nagu omaette küsimus, et kas see oli minu')},
#  {'valimised': Text(text='Et seal saaks pidada ühe suure ja vägeva rahvusvahelise jalgpallimatši, samal ajal, kui me vaatame seda riigieelarvet ja vaatame siis haridusala palgatõusu, mis ometigi nii-öelda vähemasti selle põhjal, mida meile vaid\nsellest räägitakse, on üks olulisi asju, millest Jürgen Ligi on lubanud siis seista see on vist see haridus alampalgatõus on üheksa välja üheksa miljonit ja kuulake nüüd, riik annab viis miljonit ühe jalgpallistaadioni jooksmist tänasel päeval funktsioneerib muuhulgas täitsa edukalt, eks ole.')},
#  {'vaidlused ja erimeelsused': Text(text='Võib-Olla mitte nii palju Oudekki Loone kui siis just Aadu Must, keda me teame ju ajalooliselt, kui Edgar Savisaare\nülikoolikaaslaste väga pikaajalist võitluskaaslaste veel siis, kui Edgar Savisaar võitles oma elu ja tervise pärast siinsamas Tartu Ülikooli kliinikumis siis oli Aadu Must see, kes kes tal kätt hoidis ja, ja temalt,\net maailmale sõnumeid, vahendas ja vastupidi.')},
#  {'valimised': Text(text='Ja nüüd siis pärast seda, kui Keskerakonna kongressil Aadu Musta tütar Kadri Simson kandideeris Edgar Savisaare vastu, siis siis on kõik see kõik see viiskümmend või nelikümmend viiskümmend aastat saab\njust ühe päevaga äkitselt prügikasti visatud ja saadet otsustada, otsustav aktsioon alanud Aadu Musta ja kogu tema perekonna hävitamiseks Keskerakonna ridades.')},
#  {'valimised': Text(text='Ja veel saada paar häält kuskilt, siis oleks võimalik president ära valida Riigikogus.')},
#  {'valimised': Text(text='Seni on olnud ju Keskerakonna riigikogu fraktsiooni siis\nKadri Simsoni käes tundub, et kõigi märkide järgi, et on olnud nii-öelda kontroll veel tema käes, aga aga see pisitasa on järjest murenema, siis ja, ja kindlasti saab kõva müra juurde, kui Jüri Ratas peaks valitama Eesti Olümpiakomitee esimeheks, siis on üks asjade see Savisaarele on see kindlasti meeldiv päev.')},
#  {'valitsemine': Text(text='Kaks momenti esiteks see, et see poliitiline muutus mida-mida-mida, ma silmas pidasin, oli see, et seni on teised erakonnad öelnud, et,\net seni kuni juhib Keskerakonda Edgar Savisaar, nad temaga koostööd ei tee.')},
#  {'valetamine': Text(text='ette valmistades, et Tallinna Sadam selle võidaks kuritarvitanud neid andmeid ja seda informatsiooni.')},
#  {'valitsemine': Text(text='Ja seda positsiooni, mida tal oli pidada esmalt läbi kukkunud hanke järgi teiselt erapakkujalt teades\nära kasutas, kusjuures hanke ettevalmistamisse oli isegi kaasatud ka Tallinna Sadam, kui tulevane hankevõit\nja mis oli juba valitsuse poolt eelnevalt kabinetiistungil, nii otsustatud.')},
#  {'valitsemine': Text(text='kuivõrd aga seda kogu selle teema nii-öelda politiseeritust või üle politiseeritust on kirjeldatud väga hästi ja selles lõpp, bariton parandas, on kuskil koalitsioonilepingutes kokku lepitud\nTallinna Sadam kuulub reformi huvisfäärikõik, mis Reformierakonna poolt selle sadama jaoks otsustatakse, on täitmiseks sõltumata sellest näiteks, et üldkoosolek ehk minister on teisest erakonnast ja nõukogu ei ole kuuletunud.')},
#  {'valitsemine': Text(text='Tere, siin on Kuku raadio ja siin on keskpärane Keskpäevatund no-no jah, no jah, Tartus kui mida armastan olukord on meil selline, et kolmas liige Mart Luik\nparajasti vaatab sihik läbi läbi sihiku kusagile Vene poole peale ja õppustel, nii et püüame kahekesi need lood siin täna kõik ära rääkida, mille laulis Jaan Pehk, kah Tartust\nja eks see lauluke oli nii pühendunud kõigile neile, kes tahtsid üle õlekõrre minna teisele poole või teha põhjast laeva kesta jõuda niimoodi siis edukate presidendivalimiste lõpuni juba riigikogus\nnendest kõikidest teemadest räägime ka enne seda, soovime siis head kooliaasta algust kõigile neile, kes kooli läksid ja neile, kes\nkedagi kooli saatsid, olgu need väiksed või suured, see on tähtis asi ja esindas sul õpingud lähevad Priit.')},
#  {'valimised': Text(text='Ehk siis Siim Kallas ja Mailis Reps, kus siis Siim Kallase nelikümmend kaks häält ja Mailis Repsi kakskümmend kuus häält ja Vabariigi Presidendi Riigikogus valimata juba igav seda kõike nii palju kuuldud,')},
#  {'valimised': Text(text='Eiki Nestor, seda kordas Andres Anvelt, no minu meelest oli neid veel, kes sedakorda sellega, mis, mis mõttes teist ja mis mõttes Riigikogus on siis tingimata peaks valima ja mis mõttes see on parem, kui valik')},
#  {'valimised': Text(text='Nad väidavad, et nende mõte oli see, et ikkagi üldiselt valitakse presidenti Riigikogus ja see valimiskogu on nagu noh, mõnes mõttes niisugune nagu häda ventiili abivahend, aga tegelikult me teame ju Eesti Vabariigi\nuuemast kahekümne viie aastasest ajaloost, et ainult üks kord on õnnestunud riigikogus president selle seaduse järgi ära valida, kui nüüd Toomas Hendrik Ilves viis aastat tagasi uuesti tagasi valiti, teiseks ametiajaks.')},
#  {'vaidlused ja erimeelsused': Text(text='Aga läheme sellise teema juurde, et\nmiks on erakonnad\npresidendivalimiste käigus nii palju Reformierakonda häbistanud, et nende saadikute hääled ei olnud esimese valimisvooru puhul ühtselt\nKallase taga.')},
#  {'valimised': Text(text='Ja suhteliselt oskavad nagu kahte kahe kokku liita, saavad nelja teema ei ole siiamaani aru saanud, mis neid sunnib sugust joga ajama ja teine asi on see, et see olukord, mis meil on selle Marina Kaljurannaga selge on see, et\ntal ei ole ta ei saa minna valimiskogusse, sellepärast et selliselt on ta siis ta kandideeriks Siim Kallase vastu ja see, see tõenäoliselt viik siis ära üldse igasuguse šansi, et Reformierakond saaks mõne oma kandidaadi ja president, eks, seal valida endale')},
#  {'valitsemine': Text(text='Võib-Olla eelmised peaministrid ongi nagu rohkem ise otsustama, käib\nolnud, aga eks, eks see küsimus on see, kui see tasakaalupunkt on, et kus mingil hetkel tuleb ka otsustada, et mingil hetkel noh, ei ole võimalik lõpmatuseni konsensust otsida ja ja eks see võib olla see uus põlvkond, kes praegu valmiv valitsuses on, kui Reformierakonda juhivad\nvõib-olla see nende elukogemus siis ei ole nii piisav, nii piisavalt suur, et, et õigel hetkel tunnetada, millal on vaja ära otsustada mingid asjad ja millal mitte, nii et ei tea, aga, aga kõrvalmärkusena olgu lihtsalt huvitav huvi\ntõttu huvitav märkida seda, et et üks Reformierakonna minister on nii vait olnud kui vähegi võimalik kelladest ja üldse mitte midagi, kui Valgevenega minister jagamisega meister, kelle nimi on majandus-kommunikatsiooniminister Kristen Michal, kes ministri on minu meelest päris korralikult tööd.')},
#  {'valimised': Text(text='Aga põhimõtteliselt on see paber siiski väga ärevaks tegev ja selle paberi nii-öelda mõju on\njärgmine Keskerakonna sees on palju räpaseid saladusi,\nmis kõik ei ole veel päevavalgele tulnud, aga neid tuleb veel ja veel ja igaüks, kes hakkab Keskerakonna mingisugust asja ajama või näiteks valib Kadriorgu\nMailis Repsi Keskerakonna esindajana võib karta seda, et ühel päeval ilmub kuskilt Toom-Rüütli tänavalt Keskerakonna peakontoris\nlagedale järjekordne vastik dokument, salajane dokument, mis ütleb seda, et Mailis Reps näiteks lubab teha seda teist või kolmandat või neljandat või on ja mitmesugused muud arusaamatud.')},
#  {'valitsemine': Text(text='linnapea Taavi saavad väga hea, et tegelikult linnapea juhib, juhib linna fraktsiooni juhib Kadri Simson kõik nagu vaikselt tiksub ja mingisuguseid suuri probleeme ei ole, isegi siin.')},
#  {'valimised': Text(text='See küsimus, et, et, et juhul, kui Edgar Savisaar ei kandideeri kohalikel valimistel ja et, et mis siis teeb Keskerakonna venelastest valijaskond enam siit ja siit see vastus siis tuligi, et, et meenutati neile, et, et\nkeskerakond on ikka ja ikka ja jälle nendega.')},
#  {'valetamine': Text(text='Nüüd on siis lahvatanud selline, mitte nüüd skandaal, aga skandaalikese mis siis\ntähendab seda, et selle Arsenali keskuse müügi kohal, mille siis Riigi Kinnisvara Aktsiaselts pani kahe tuhande kaheteistkümnel aastal müüki ja müüs praegustele omanikele, et nagu nüüd on selgunud, oli nende ostjate hulgas oli siis ka härra Nilsson\nehk krooniga jah, versiooniga ja oli ka härra Nilsson ehk siis Rain Rosimannusele Härra Nilssoni nimetas asi\nKeskpäevatunnis, kes istus Reformierakonna juhatuse koosolekutel nagu härra Nilsson mäletate aafriklane Pipi lugudes, kes ei olnud küll kuhugi valitud ja ametikohta ei olnud, aga oli alati suure laua ääres ja juhtis ka juba ja õpetas teisi, kuidas asjad peaks tegema ja nüüd, kuna\nriigi Kinnisvara aktsiaseltsi tol ajal juhtis, siis vahepealne peaminister Taavi Rõivas, siis nüüd ongi tekkinud suur probleem, et kas Taavi Rõivas oli teadlik\nsellest, et Rain Rosimannusele on varjatud osalus ja kaasselle müügiga need kõik asjad on puhtad.')},
#  {'valimised': Text(text='ülesehitamine Vene küsimusele tagab neile Savisaarel, kas Savisaar kandideerib või mitte, nii et see on kahetsusväärne, et niivõrd lühinägelikult aetakse poliitikat, ma ei räägi, et see\nnagu lõhestab ühiskonda ja, ja me peame aru saama, et mis on nii-öelda poliitika ja mis on lihtsalt valimis.')},
#  {'vaidlused ja erimeelsused': Text(text='Nii et, et jah, aga see, et, et seal ELi siseselt nüüd Reinsaluga nokitakse, eks noh\net jõu jõumehed jõudu')},
#  {'vaidlused ja erimeelsused': Text(text='IRL haaras ka rongi otsast kinni, lohiseb selle järgi üldine arvamus läheb sinna, nad kõik haaravad sellest kinni, hoiavad kahe käega sellest on\ntingitud osalt ka siis nii-öelda sotside ja Jevgeni Ossinovski selline käre, käre kisa, et mitte öelda käre sõim, siis nii-öelda konservatiivide osas vastandub väga võimsalt ennast praegu IRLile ja ekraanile ütleb, et\ntuleb tuld ja tõrva hakkab tulema, kui sellised inimesed pääsevad võimu juurde.')},
#  {'valitsemine': Text(text='Aga, aga nagu ajakirjanikud ikka, hakkame nüüd nokkima ja norima ja kui me võtame ette selle Forbesi\nprofiili, mis on meie presidendist kirjutatud, siis algab sõnadega, et Kaljulaid juhi\nvaikselt digitaalset revolutsiooni pisikeses Eestis, kus ta on riigi esimene nais\npresident ja siis tuleb edasi, et Eesti on esimene riik, mis digiteerida oma avalikud teenused, sealhulgas ka valimised.')},
#  {'valitsemine': Text(text='Ja tervishoiu ja, ja koolisüsteemi ja kõik see lugu siin lõpeb sellega, et praegu siis Kersti Kaljulaid\njuhib suurt ettevõtmist, mille nimi on krüptoraha arendamine, selline riiklikult tagatud krüptoraha mis, mille nimi on Estcoy.')},
#  {'valimised': Text(text='Või esitab IRL oma kandidaadi, millel on šanss\nläbi minna ja tõepoolest, et kui sinna ajalehed imestavad, et mispärast Mart Luik kust need hääled võttis, siis loomulikult ta võttis need hääled siis, kui keskerakondlased olid korraks kogunenud oma tuppa, tulid sealt välja osa neist naeratas Mardi poole ja seejärel hääletati, oligi Mart valitud, et kas siis see, kui Rajasalu oleks\nläbikukkunud, kas see oleks olnud siis nagu positiivne tulemus kogu sellele sündmusele,')},
#  {'valimised': Text(text='Et näiteks Riigikogus, kui neid aseesimehed valitakse siis neid hääletatakse ühe korraga.')},
#  {'valetamine': Text(text='No läksidki kardinaalselt lahku, Siiri Sisask ei varjanud seda, et ta on\nsamasooliste kooselu suhtes tolerantne.')},
#  {'valitsemine': Text(text='iga detail, tuleb üle käia, et teha kindlaks, millega see detail tegeleb, ega muud ei olegi, aga aga\nminu arust sellest ajast, kui Jüri Ratas Keskerakonna esimeheks on vaikselt-vaikselt see Keskerakonna e-valimiste tees muutunud, et niikaua kuni Edgar Savisaar punti juhtis, oli ju väga häälekalt see, kuidas e-valimised on saatanast.')},
#  {'vaidlused ja erimeelsused': Text(text='Ehk siis mulle jäi kohati isegi selline mulje, et president kinnitas selle amet valitsuse ametisse ja ei läinud vaidlusesse vaidlema Riigikohtusse ja ei läinud põhiseaduse vastuollu.')},
#  {'valimised': Text(text='Reinsalu nüüd on lubanud selle asja ümber teha aastaks kaks tuhat kakskümmend kaks, et saab elektrooniliselt taotleda üle maailma ja passise.')},
#  {'valimised': Text(text='Nüüd kas see Riigikogu liikmeid, kes hääletasid siis Rail Baltica poolt, said sellest niimoodi aru et hakkama ise seda kinni maksma, võib tõesti mürki võtta, et, et see niimoodi olnud, ehk siin on juba täiesti uued aspektid, võib-olla võib öelda juba sadu miljoneid eurosid, mis on kasutamata jäänud, kes selle eest vastutab, ka selle eest hakkab vastutama ma majandusministeerium.')},
#  {'valimised': Text(text='Et kui palju inimesi tuleb siis, kui nad langetavad viisteist protsenti ja kui palju kahekümne ja kui palju kolmekümne protsendi peale, et see, et nad ei osanud ette näha, see on kahtlemata jamaga, mis teisest küljest ei, ei ei anna mingisugust alust selleks, et mit te uskuda selle omaniku siirast kahetsust, et läks nagu kehvasti, et seda, mida ta muidugi, seda võib ikka uskuda, aga ma tahtsin küsida, et kas sel nädalal üks, üks veidramaid uudiseid igasuguste Korona uudiste hulgas oli Tartu keskerakondlase Jaan Tootsi määramine siis Ettevõtluse Arendamise Sihtasutuse nõukogu liikmeks, et see on küll üks selline asi, mis minus tekitas nagu sügavat arusaamatust ja ma ei saanud aru, et et mida võidab sellest eAS ja mitte ja mida võidab Jaan Toots, aga ma tahaks kangesti teada mõlemale küsimusele vastust.')},
#  {'valitsemine': Text(text='Nüüd arendajad on siis teinud ettepaneku, et sinna ei tehta mingit pumplat ja sellist nagu süvatorustik ka, et see kõik on, tehakse kraavid ja siis immutamine ja see kõik suunatakse siis mööda kitsast riba sinna mere poole ja Tallinna linn ei ole sellega nõus ja nüüd toimub selline avalik kemplus, kus siis arendaja ütles, et okei, et me oleme saanud projekteerimistingimused kätte mingeid pumplat, meie ehitaja, siis teeme need kraavid ja siis või midagi taolist, et ma lihtsalt püüan, nagu seda me aint tsiteerivad, püüan seda olukorda edasi anda, et kõik on korras, me saame ehitama hakata ja kohe siis umbes natuke aega pärast seda, kui arendaja selle informatsiooni laseb välja, teatab Tallinna abilinnapea Kalle Klandorf ütleb, et mitte midagi taolist ei ole, et see on täielik jama, et ma ei ole andnud mingisugust õigust lihtsamal viisil seda teha, et et Tallinna Tehnikaülikoolist toodi üks ekspertiis, mis ütleb, et jah, et mööda kitsast riba saaks selle vee juhtida sinna mere poole, aga Tallinna linn sellega nõus ei ole, on selge, et seal on palju inimesi, et need probleemid, kui praegu minna lihtsamat teed, siis need probleemid hiljem alles tekivad.')}]
